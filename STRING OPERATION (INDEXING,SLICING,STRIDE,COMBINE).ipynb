# %% [markdown]
# # String Operations PART 2
#
#   **1-POSITIVE INDEXING**
#
#   **2-NEGATIVE INDEXING**
#
#   **3-SLICING**
#
#   **4-STRIDE**
#
#   **5-CONCATENATE STRING**(**COMBINE STRING**)

# %% [markdown]
# ## 1. POSITIVE INDEXING

# %% [markdown]
#  ### [Tip]: Because indexing starts at 0, it means the first index is on the index 0.

# %%
name= "michael jackson"
name[0]
# Out:
# 'm'

# %%
name[6]
# Out:
# 'l'

# %%
name[13]
# Out:
# 'o'

# %% [markdown]
# ## 2. NEGATIVE INDEXING
# ### Negative index can help us to count the element from the end of the string.
# ### START WITH -1

# %%
name= "michael jaclkson"
name[-1]
# Out:
# 'n'

# %%
name[-15]
# Out:
# 'i'

# %% [markdown]
# # NOTE: LENGTH OF THE STRING

# %%
len("michael jaclkson")
# Out:
# 16

# %% [markdown]
# # 3. SLICING

# %% [markdown]
# ## NAME :"MICHAEL JACKSON"
# ## We can obtain multiple characters from a string using slicing, we can obtain the 0 to 4th and 8th to the 12th element:

# %%
name:"micheal jakson"
name[0:4]
# Out:
# 'mich'

# %%
name[8:12]
# Out:
# 'jacl'

# %% [markdown]
# # 4. Stride

# %% [markdown]
# ## NAME : "MICHAEL JACKSON"
# ## We can also input a stride value as follows, with the '2' indicating that we are selecting every second variable:

# %%
name[::2]
# Out:
# 'mcaljcko'

# %% [markdown]
# ## Get every second element in the range from index 0 to index 4

# %%
name[0:5:2]
# Out:
# 'mca'

# %% [markdown]
# # 5. Concatenate Strings

# %% [markdown]
# ## We can concatenate or combine strings by using the addition symbols, and the result is a new string that is a combination of both:

# %%
S1= name +"is the best"
print(S1)
# Out:
# michael jaclksonis the best

# %% [markdown]
# ### NOTE : PRINT THE STRING

# %%
3*S1
# Out:
# 'michael jaclksonis the bestmichael jaclksonis the bestmichael jaclksonis the best'
